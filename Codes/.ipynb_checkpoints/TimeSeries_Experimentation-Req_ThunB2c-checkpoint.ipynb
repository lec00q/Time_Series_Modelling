# %% [markdown]
# #### Objective : Univariate Time Series Modelling using DARTS for model training and weight & Biases for model logging to beat the becnhmark model already provided
#
# #### Created By : Ashwini Kumar
#
# #### Start Date : 16th March 2022
#
# #### Steps Involved :
#
#     1. Read the data from the csv file and split into train and validation splits
#
#     2. Define the Variables to be tuned and define the error function for benchmarking
#
#     3. Define the Weight & Bias Initialization using API Key
#
#     4. Use Sweep to do hyperparam tuning in the data
#
#     5. Log the data to Weight & Bias to see the results

# %%
# Import the required packages 
# Import the required packages 
from darts import TimeSeries
import pandas as pd
import tqdm as notebook_tqdm
from darts.dataprocessing.transformers import Scaler
from darts.models import RNNModel, ExponentialSmoothing, BlockRNNModel
from darts.metrics import mape
from darts.utils.statistics import check_seasonality, plot_acf
from darts.datasets import AirPassengersDataset, SunspotsDataset
from darts.utils.timeseries_generation import datetime_attribute_timeseries
import wandb ## Function for weights and biases
import plotly
from darts import TimeSeries
from darts.dataprocessing.transformers import Scaler
from darts.models import RNNModel, ExponentialSmoothing, BlockRNNModel,NBEATSModel,TransformerModel,AutoARIMA,TFTModel
from darts.metrics import mape
from darts.utils.statistics import check_seasonality, plot_acf
from darts.datasets import AirPassengersDataset, SunspotsDataset
from darts.utils.timeseries_generation import datetime_attribute_timeseries
from darts.models import TCNModel, RNNModel
from darts.models import FFT, AutoARIMA, ExponentialSmoothing, Prophet, Theta
import os
# Remove Noise using the Gaussian Wave
from darts.models.forecasting.regression_ensemble_model import RegressionEnsembleModel
from sklearn.gaussian_process.kernels import ExpSineSquared, RBF
from darts.models import GaussianProcessFilter
import matplotlib.pyplot as plt
# from darts import ModelMode
from darts.utils.utils import SeasonalityMode,ModelMode

# %%
# Function to read the csv file from given location & parse datetime properly
def load_dataframe(filename):
    df = pd.read_csv(filename)
    df["Date"] = pd.to_datetime(df["Date"])
    return df

# Function create the Time Series from Dataframe using a Time Series to df function
def df_to_timeseries(df,time_column, timeseries):
    series = TimeSeries.from_dataframe(df, time_column,timeseries)
    return (series)

# Define the Mean Absolute Error for evaluating our model
from darts.metrics import mae
def eval_error(actual_values,pred_values):
    return mae(actual_values,pred_values)

# Call the function to read the data properly

df = load_dataframe("C:\\Users\\ashwini.kumar\\Time_Series_Modelling\\_Final_master_df_2022_2017_v9_with_Bolzano.csv")
df.head(5)
# Out:
#         Date  RequestedQTY  GoodsIssuedQTY  InvoicedQTY  PDO number  req_Illy  \
# 0 2016-12-26        1616.0          1613.0       1613.0         135     635.0
# 1 2017-01-02      227928.0        217034.0     216049.0       12075   12851.0
# 2 2017-01-09      176524.0        167839.0     166669.0       10663   14442.0
# 3 2017-01-16      289548.0        280089.0     279048.0       12330   14555.0
# 4 2017-01-23      248337.0        234044.0     232787.0       15942   15244.0
#
#    req_Teddy  req_Thun  req_other  inv_Illy  ...  BOL_B2B AA Thun  \
# 0        0.0     981.0        0.0     635.0  ...              NaN
# 1        0.0  215041.0       36.0   11866.0  ...              NaN
# 2        0.0  162078.0        4.0   13272.0  ...              NaN
# 3        0.0  274961.0       32.0   13514.0  ...              NaN
# 4        0.0  233063.0       30.0   13987.0  ...              NaN
#
#    BOL_B2B P&P Thun  BOL_B2B Sorter Thun  BOL_B2B Sorter SM Thun  \
# 0               NaN                  NaN                     NaN
# 1               NaN                  NaN                     NaN
# 2               NaN                  NaN                     NaN
# 3               NaN                  NaN                     NaN
# 4               NaN                  NaN                     NaN
#
#    BOL_B2B Sorter BVB Thun  BOL_B2B Sorter riassortimenti WHS  BOL_B2C Thun  \
# 0                      NaN                                NaN           NaN
# 1                      NaN                                NaN           NaN
# 2                      NaN                                NaN           NaN
# 3                      NaN                                NaN           NaN
# 4                      NaN                                NaN           NaN
#
#    BOL_B2C Sorter Thun  BOL_B2C P2L Thun  BOL_Inbound Thun
# 0                  NaN               NaN               NaN
# 1                  NaN               NaN               NaN
# 2                  NaN               NaN               NaN
# 3                  NaN               NaN               NaN
# 4                  NaN               NaN               NaN
#
# [5 rows x 61 columns]

# %%
help(df_to_timeseries)
# Out:
# Help on function df_to_timeseries in module __main__:
#
# df_to_timeseries(df, time_column, timeseries)
#     # Function create the Time Series from Dataframe using a Time Series to df function

# %%
# Use the ThunB2B sorter values and split
timeseries_input = df_to_timeseries(df,"Date","req_ThunB2C")

benchmark_input = df_to_timeseries(df,"Date","BOL_B2C Thun")

# Set aside the data since 2021 
train_data, val_data = timeseries_input.split_before(pd.Timestamp('2021-01-04'))

train_benchmark_ignore, benchmark_data = benchmark_input.split_before(pd.Timestamp('2021-01-04'))

timeseries_input.plot(color="red", label="Noisy Time Series")
    
plt.legend()

# %%
from darts.metrics import mae
def eval_error(actual_values,pred_values):
    return mae(actual_values,pred_values)

# %%
# The function to define the train_data input data and other functions
def call_timeseries(train_column,benchmark_column):
    timeseries_input = df_to_timeseries(df,"Date",train_column)
#     print (timeseries_input)

    benchmark_input = df_to_timeseries(df,"Date",benchmark_column)
    # Set aside the data since 2021 
    
    kernel = ExpSineSquared()
    # kernel = RBF()

    gpf = GaussianProcessFilter( kernel=kernel, alpha=0.2 / 2, n_restarts_optimizer=100)
    
    filtered_x = gpf.filter(df_to_timeseries(df,"Date",train_column))
                            
    plt.figure(figsize=[12, 8])
    timeseries_input.plot(color="red", label="Noisy Time Series")
    filtered_x.plot(color="blue", label="Filtered Time Series")
    plt.legend()
#     plt.savefig(series_name + 'filtered' + "/" + train_column + '.png')

    train_data , val_data_filtered = filtered_x.split_before(pd.Timestamp('2021-01-04'))

    train_data_noisy, val_data = timeseries_input.split_before(pd.Timestamp('2021-01-04'))

    train_benchmark_ignore, benchmark_data = benchmark_input.split_before(pd.Timestamp('2021-01-04'))
    
    return train_data,val_data,benchmark_data,timeseries_input


train_series = ["req_ThunB2C"]
benchmark_series = ["BOL_B2C Thun"]

# train_series = ['Sum_All_Variables' ]
# benchmark_series = ['Sum_All_Variables_Benchmark']


for i in range(len(train_series)):
    
    print ("Running for " , train_series[i])
    train_data,val_data,benchmark_data,timeseries_input = call_timeseries(train_series[i],benchmark_series[i])
    print ("Call the training function")
# Out:
# Running for  req_ThunB2C
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\sklearn\gaussian_process\_gpr.py:610: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# Call the training function

# %%
# model = RegressionEnsembleModel([ Prophet(),Prophet(n_changepoints = 5, changepoint_range = .95),
#                               Prophet(n_changepoints = 10, changepoint_range = .95)  ],regression_train_n_points=12)
# print ("Fitting the Model with Deafults Params :",mo,del_type)
# Fit the model on training dat
model=ExponentialSmoothing(trend = ModelMode.ADDITIVE,damped=False, seasonal=SeasonalityMode.ADDITIVE, seasonal_periods=52)
model_req = model.fit(train_data)
#Make the prediction for 58 observation on train Data
pred_air = model_req.predict(n = 58)

#             print (pred_air)
# Predict the data for Backtesting
#             if num <= 4:
#                 pred_backtest = model.historical_forecasts(timeseries_input,
#                   start=pd.Timestamp("2020-12-28"),  forecast_horizon=4)
#             else:
#                 pred_backtest = model.historical_forecasts(timeseries_input,
#                   start=pd.Timestamp("2020-12-28"),  forecast_horizon=8, retrain=False)
#             print (pred_backtest)
#             print (len(pred_backtest))
# Calculate the loss off model
loss_model = mae(val_data , pred_air)
#Calculate the loss of bencmark model
loss_benchmark = mae(val_data, benchmark_data)
# Calculate the loss off backtesting
#             loss_backtesting = mae(val_data,pred_backtest)
# Print the loss function for benchmark data
print ("Benchmark Loss is :", loss_benchmark) 
# Print the loss function for benchmark data
print ("Model Predict Loss is :", loss_model)      
# Print the loss function for benchmark data
#             print ("Model Backtest Loss is :", loss_backtesting)  

# Initialize the plotting variables


# Set the image size
plt.rcParams["figure.figsize"] = (20,8)
# Plot the actual time series data
val_data.plot()
# Plot the prediction made
pred_air.plot(label='Model Predictions', low_quantile=0.05, high_quantile=0.95)
benchmark_data.plot(label='benchmark data', low_quantile=0.05, high_quantile=0.95)
#             pred_backtest.plot(label='Backtesting Predictions', low_quantile=0.05, high_quantile=0.95)
plt.legend()
# Out:
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Benchmark Loss is : 4774.6551724137935
# Model Predict Loss is : 5372.490129180126

# %%
## Lets Initialise the weight & biases and tune the hyperparams for Nbeats model to see how it performs

# %%
# !pip install wandb -qqq
# !pip install plotly
import wandb
import plotly
# Out:
# Requirement already satisfied: plotly in c:\users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages (5.6.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in c:\users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages (from plotly) (1.16.0)

# %%
# Login to Weight & Biases 
wandb.login()
# Out:
# wandb: Currently logged in as: fibonacciash (use `wandb login --relogin` to force relogin)
# True

# %%
# Define SWEEP function in DARTS and record all the hyperparams
wandb.init(project="TimeSeries-req_ThunB2C", entity="fibonacciash")
sweep_config = {
  "name" : "my-sweep",
  "method" : "grid",
  "parameters" : {
#       "trend" : {"values" :[ModelMode.ADDITIVE, ModelMode.MULTIPLICATIVE,ModelMode.NONE]},
    "damped" :{"values" : [True,False]},
#      "seasonal":{"values":[SeasonalityMode.ADDITIVE, SeasonalityMode.MULTIPLICATIVE, SeasonalityMode.NONE]},
    "seasonal_periods" :{"values":[4,8,16,24,32,52,53,56,60,72]} 
       }        }
      ## For prophet
#       "seasonality_mode" : {"values":['additive','multiplicative']},
#       "n_changepoints" : {"values" : [5,10,20,30,40,50,60,70,80]},
#       "changepoint_range" : {"values" : [0.5,0.6,0.7,0.8,0.9]},
#       "seasonality_prior_scale" : {"values" :[5,10,20,30,40,50]}
            


sweep_id = wandb.sweep(sweep_config)
import pprint
pprint.pprint(sweep_config)
# Out:
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Finishing last run (ID:ckalq5am) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">resilient-sweep-6</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/ckalq5am" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/ckalq5am</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_155922-ckalq5am\logs</code>
# Successfully finished last run (ID:ckalq5am). Initializing new run:<br/>
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_155946-ckalq5am</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/ckalq5am" target="_blank">resilient-sweep-6</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/i2qxqhk5" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/i2qxqhk5</a>
# Create sweep with ID: 9lftbjsf
# Sweep URL: https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf
# {'method': 'grid',
#  'name': 'my-sweep',
#  'parameters': {'damped': {'values': [True, False]},
#                 'seasonal_periods': {'values': [4,
#                                                 8,
#                                                 16,
#                                                 24,
#                                                 32,
#                                                 52,
#                                                 53,
#                                                 56,
#                                                 60,
#                                                 72]}}}

# %%
wandb.init(project="TimeSeries-req_ThunB2C", entity="fibonacciash")
def train():
    with wandb.init() as run:
        config = wandb.config

       
 # your model training code here

  
        model = ExponentialSmoothing(damped=config.damped, 
                                      seasonal_periods=config.seasonal_periods)
        # fitting the model
        model_req = model.fit(train_data)

        pred_air = model_req.predict(n = 58)


        loss = mae(val_data , pred_air)

        loss_benchmark = mae(val_data, benchmark_data)
        ## Log the absolute Error
        wandb.log({"loss_train": loss})  
        ## 
        wandb.log({"loss_benchmark": loss_benchmark})  
        plt.figure()
        plt.rcParams["figure.figsize"] = (20,8)
        timeseries_input.plot()
        model.predict(n = 58).plot(label='forecast', low_quantile=0.05, high_quantile=0.95)
        benchmark_data.plot()
        plt.legend()
        plot_image = wandb.Image(plt)
        wandb.log({"chart" : plot_image})

count = 30 # number of runs to execute
wandb.agent(sweep_id, function=train)
# Out:
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Finishing last run (ID:ckalq5am) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">resilient-sweep-6</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/ckalq5am" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/ckalq5am</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_155946-ckalq5am\logs</code>
# Successfully finished last run (ID:ckalq5am). Initializing new run:<br/>
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160012-ckalq5am</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/ckalq5am" target="_blank">resilient-sweep-6</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/i2qxqhk5" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/i2qxqhk5</a>
# wandb: WARNING Calling wandb.login() after wandb.init() has no effect.
# wandb: Agent Starting Run: ao4y3htm with config:
# wandb: 	damped: True
# wandb: 	seasonal_periods: 4
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160027-ao4y3htm</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/ao4y3htm" target="_blank">charmed-sweep-1</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.072 MB of 0.072 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>5464.29028</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">charmed-sweep-1</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/ao4y3htm" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/ao4y3htm</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160027-ao4y3htm\logs</code>
# wandb: Agent Starting Run: i3y7zyft with config:
# wandb: 	damped: True
# wandb: 	seasonal_periods: 8
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160049-i3y7zyft</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/i3y7zyft" target="_blank">curious-sweep-2</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.073 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.012238…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>6016.9987</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">curious-sweep-2</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/i3y7zyft" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/i3y7zyft</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160049-i3y7zyft\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 9c827dyb with config:
# wandb: 	damped: True
# wandb: 	seasonal_periods: 16
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160115-9c827dyb</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/9c827dyb" target="_blank">zesty-sweep-3</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.074 MB of 0.074 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>6974.92849</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">zesty-sweep-3</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/9c827dyb" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/9c827dyb</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160115-9c827dyb\logs</code>
# wandb: Agent Starting Run: ke8m3h4k with config:
# wandb: 	damped: True
# wandb: 	seasonal_periods: 24
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160138-ke8m3h4k</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/ke8m3h4k" target="_blank">dainty-sweep-4</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.075 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011893…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>8878.79569</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dainty-sweep-4</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/ke8m3h4k" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/ke8m3h4k</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160138-ke8m3h4k\logs</code>
# wandb: Agent Starting Run: 3ogix9mb with config:
# wandb: 	damped: True
# wandb: 	seasonal_periods: 32
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160200-3ogix9mb</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/3ogix9mb" target="_blank">wise-sweep-5</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.075 MB of 0.075 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>6093.72822</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">wise-sweep-5</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/3ogix9mb" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/3ogix9mb</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160200-3ogix9mb\logs</code>
# wandb: Agent Starting Run: tv10xvws with config:
# wandb: 	damped: True
# wandb: 	seasonal_periods: 52
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160222-tv10xvws</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/tv10xvws" target="_blank">efficient-sweep-6</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.075 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011893…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>4038.15596</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">efficient-sweep-6</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/tv10xvws" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/tv10xvws</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160222-tv10xvws\logs</code>
# wandb: Agent Starting Run: 9eksxqio with config:
# wandb: 	damped: True
# wandb: 	seasonal_periods: 53
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160244-9eksxqio</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/9eksxqio" target="_blank">deft-sweep-7</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.075 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011819…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>5875.57439</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">deft-sweep-7</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/9eksxqio" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/9eksxqio</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160244-9eksxqio\logs</code>
# wandb: Agent Starting Run: nkiqdq38 with config:
# wandb: 	damped: True
# wandb: 	seasonal_periods: 56
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160306-nkiqdq38</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/nkiqdq38" target="_blank">denim-sweep-8</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.077 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011541…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>10826.00749</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">denim-sweep-8</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/nkiqdq38" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/nkiqdq38</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160306-nkiqdq38\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 9ahia3dq with config:
# wandb: 	damped: True
# wandb: 	seasonal_periods: 60
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160338-9ahia3dq</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/9ahia3dq" target="_blank">wise-sweep-9</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.077 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011585…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>9305.47451</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">wise-sweep-9</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/9ahia3dq" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/9ahia3dq</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160338-9ahia3dq\logs</code>
# wandb: Agent Starting Run: 0u6ncwrc with config:
# wandb: 	damped: True
# wandb: 	seasonal_periods: 72
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160402-0u6ncwrc</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/0u6ncwrc" target="_blank">true-sweep-10</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.077 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011625…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>9625.71171</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">true-sweep-10</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/0u6ncwrc" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/0u6ncwrc</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160402-0u6ncwrc\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: epp49ocw with config:
# wandb: 	damped: False
# wandb: 	seasonal_periods: 4
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160434-epp49ocw</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/epp49ocw" target="_blank">avid-sweep-11</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.073 MB of 0.073 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>10707.6995</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">avid-sweep-11</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/epp49ocw" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/epp49ocw</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160434-epp49ocw\logs</code>
# wandb: Agent Starting Run: 8q7mnedm with config:
# wandb: 	damped: False
# wandb: 	seasonal_periods: 8
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160502-8q7mnedm</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/8q7mnedm" target="_blank">eager-sweep-12</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.032 MB of 0.068 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.471639…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>10623.55681</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">eager-sweep-12</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/8q7mnedm" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/8q7mnedm</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160502-8q7mnedm\logs</code>
# wandb: Agent Starting Run: sxulubnp with config:
# wandb: 	damped: False
# wandb: 	seasonal_periods: 16
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160530-sxulubnp</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/sxulubnp" target="_blank">vital-sweep-13</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.075 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011928…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>5739.92559</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">vital-sweep-13</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/sxulubnp" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/sxulubnp</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160530-sxulubnp\logs</code>
# wandb: Agent Starting Run: r17dix9l with config:
# wandb: 	damped: False
# wandb: 	seasonal_periods: 24
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160557-r17dix9l</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/r17dix9l" target="_blank">restful-sweep-14</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.075 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011916…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>8119.41873</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">restful-sweep-14</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/r17dix9l" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/r17dix9l</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160557-r17dix9l\logs</code>
# wandb: Agent Starting Run: 42a9whfl with config:
# wandb: 	damped: False
# wandb: 	seasonal_periods: 32
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160624-42a9whfl</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/42a9whfl" target="_blank">lunar-sweep-15</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.075 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011922…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>5064.94041</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">lunar-sweep-15</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/42a9whfl" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/42a9whfl</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160624-42a9whfl\logs</code>
# wandb: Agent Starting Run: 52tn3xcs with config:
# wandb: 	damped: False
# wandb: 	seasonal_periods: 52
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160652-52tn3xcs</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/52tn3xcs" target="_blank">whole-sweep-16</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.075 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011853…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>5372.49013</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">whole-sweep-16</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/52tn3xcs" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/52tn3xcs</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160652-52tn3xcs\logs</code>
# wandb: Agent Starting Run: pps2ahn4 with config:
# wandb: 	damped: False
# wandb: 	seasonal_periods: 53
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160719-pps2ahn4</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/pps2ahn4" target="_blank">grateful-sweep-17</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.076 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011771…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>7352.1747</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">grateful-sweep-17</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/pps2ahn4" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/pps2ahn4</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160719-pps2ahn4\logs</code>
# wandb: Agent Starting Run: pypsznzi with config:
# wandb: 	damped: False
# wandb: 	seasonal_periods: 56
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160746-pypsznzi</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/pypsznzi" target="_blank">quiet-sweep-18</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.077 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011566…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>9898.66022</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">quiet-sweep-18</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/pypsznzi" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/pypsznzi</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160746-pypsznzi\logs</code>
# wandb: Agent Starting Run: n4sp4ik3 with config:
# wandb: 	damped: False
# wandb: 	seasonal_periods: 60
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160813-n4sp4ik3</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/n4sp4ik3" target="_blank">revived-sweep-19</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.076 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011653…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>8003.97956</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">revived-sweep-19</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/n4sp4ik3" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/n4sp4ik3</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160813-n4sp4ik3\logs</code>
# wandb: Agent Starting Run: 5yshj5rw with config:
# wandb: 	damped: False
# wandb: 	seasonal_periods: 72
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>C:\Users\ashwini.kumar\Time_Series_Modelling\Codes\wandb\run-20220328_160841-5yshj5rw</code>
# Syncing run <strong><a href="https://wandb.ai/fibonacciash/uncategorized/runs/5yshj5rw" target="_blank">worldly-sweep-20</a></strong> to <a href="https://wandb.ai/fibonacciash/uncategorized" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf" target="_blank">https://wandb.ai/fibonacciash/uncategorized/sweeps/9lftbjsf</a>
# C:\Users\ashwini.kumar\source\repos\anaconda3\envs\practice\lib\site-packages\statsmodels\tsa\holtwinters\model.py:917: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.076 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.011660…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>▁</td></tr><tr><td>loss_train</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss_benchmark</td><td>4774.65517</td></tr><tr><td>loss_train</td><td>9107.35111</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">worldly-sweep-20</strong>: <a href="https://wandb.ai/fibonacciash/uncategorized/runs/5yshj5rw" target="_blank">https://wandb.ai/fibonacciash/uncategorized/runs/5yshj5rw</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20220328_160841-5yshj5rw\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.
